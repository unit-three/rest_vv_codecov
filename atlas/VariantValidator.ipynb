# %% [markdown]
# git+https://github.com/openvar/variantValidator@master#egg=VariantValidator
#
# https://github.com/al-baba/rest_variantValidatorFORK/blob/re-create2/rest_variantValidator/app.py
#
# https://github.com/openvar/rest_variantValidator/commit/d865469f5a899d6b3211be1b209009f79342c941
#
# https://docs.pytest.org/en/7.4.x/getting-started.html#getstarted
# https://app.codecov.io/gh/openvar/rest_variantValidator/blob/development4/rest_VariantValidator%2Fendpoints%2Fvariantvalidator_endpoints.py

# %%
! pip install git+https://github.com/openvar/variantValidator@master#egg=VariantValidator
# Out:
# Collecting VariantValidator
#   Cloning https://github.com/openvar/variantValidator (to revision master) to /tmp/pip-install-vrscfg1o/variantvalidator_0ed4faf8357b48a6bae28c44e646fb98
#   Running command git clone --filter=blob:none --quiet https://github.com/openvar/variantValidator /tmp/pip-install-vrscfg1o/variantvalidator_0ed4faf8357b48a6bae28c44e646fb98
#   Resolved https://github.com/openvar/variantValidator to commit c16e253c28220a70494dfb285df4d5c89fcebce2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vvhgvs@ git+https://github.com/openvar/vv_hgvs@master
#   Cloning https://github.com/openvar/vv_hgvs (to revision master) to /tmp/pip-install-vrscfg1o/vvhgvs_625657e43a8b4b21ba65f373551bc6d2
#   Running command git clone --filter=blob:none --quiet https://github.com/openvar/vv_hgvs /tmp/pip-install-vrscfg1o/vvhgvs_625657e43a8b4b21ba65f373551bc6d2
#   Resolved https://github.com/openvar/vv_hgvs to commit 69b1a7c107f3bba1bb43ef1de19c22ba62ff4c80
#   Preparing metadata (setup.py) ... done
# Collecting VariantFormatter@ git+https://github.com/openvar/variantFormatter@master
#   Cloning https://github.com/openvar/variantFormatter (to revision master) to /tmp/pip-install-vrscfg1o/variantformatter_a31971456d20442b9fafe14504ff243c
#   Running command git clone --filter=blob:none --quiet https://github.com/openvar/variantFormatter /tmp/pip-install-vrscfg1o/variantformatter_a31971456d20442b9fafe14504ff243c
#   Resolved https://github.com/openvar/variantFormatter to commit 0a5aaf57b1beba8f8b887ce35d0741c5c6597c33
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting configparser>=3.5.0
#   Downloading configparser-5.3.0-py3-none-any.whl (19 kB)
# Collecting pyliftover>=0.3
#   Downloading pyliftover-0.4.1-py3-none-any.whl (12 kB)
# Collecting biocommons.seqrepo>=0.5.1
#   Using cached biocommons.seqrepo-0.6.5-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: biopython in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from VariantValidator) (1.80)
# Collecting pytest-cov
#   Downloading pytest_cov-4.1.0-py3-none-any.whl (21 kB)
# Collecting httplib2>=0.9.0
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Collecting pytest>=3.6
#   Downloading pytest-7.4.4-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting protobuf
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.0.33-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/27.4 MB 167.7 kB/s eta 0:00:0000:0100:04
# Collecting codecov
#   Using cached codecov-2.1.13-py2.py3-none-any.whl (16 kB)
# Collecting pytest-xdist
#   Downloading pytest_xdist-3.5.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 455.6 kB/s eta 0:00:00:--:--
# Collecting biotools>=0.3.0
#   Using cached biotools-1.2.12.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from VariantValidator) (1.21.6)
# Requirement already satisfied: requests in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from VariantValidator) (2.28.2)
# Collecting pysam
#   Downloading pysam-0.22.0-cp37-cp37m-manylinux_2_28_x86_64.whl (23.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 186.2 kB/s eta 0:00:0000:0100:04
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: ipython in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from biocommons.seqrepo>=0.5.1->VariantValidator) (7.34.0)
# Collecting requests-html
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting yoyo-migrations
#   Using cached yoyo_migrations-8.2.0-py3-none-any.whl (48 kB)
# Collecting bioutils>0.4
#   Using cached bioutils-0.5.7-py2.py3-none-any.whl (257 kB)
# Requirement already satisfied: six in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from biocommons.seqrepo>=0.5.1->VariantValidator) (1.16.0)
# Collecting tqdm
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 463.0 kB/s eta 0:00:00a 0:00:01
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from pytest>=3.6->VariantValidator) (6.0.0)
# Collecting iniconfig
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting tomli>=1.0.0
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from pytest>=3.6->VariantValidator) (23.0)
# Collecting coverage
#   Downloading coverage-7.2.7-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.6/225.6 kB 2.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from requests->VariantValidator) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from requests->VariantValidator) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from requests->VariantValidator) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from requests->VariantValidator) (2022.12.7)
# Collecting protobuf
#   Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 195.0 kB/s eta 0:00:0000:0100:01
# Collecting execnet>=1.1
#   Downloading execnet-2.0.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: attrs>=17.4.0 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from vvhgvs@ git+https://github.com/openvar/vv_hgvs@master->VariantValidator) (22.2.0)
# Collecting enum34
#   Using cached enum34-1.1.10-py3-none-any.whl (11 kB)
# Collecting ipython
#   Using cached ipython-5.10.0-py3-none-any.whl (760 kB)
# Collecting parsley
#   Using cached Parsley-1.3-py2.py3-none-any.whl (88 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 196.3 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest>=3.6->VariantValidator) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest>=3.6->VariantValidator) (3.11.0)
# Requirement already satisfied: setuptools>=18.5 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (65.6.3)
# Requirement already satisfied: decorator in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (5.1.1)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Using cached prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
# Requirement already satisfied: pickleshare in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (5.8.1)
# Requirement already satisfied: pexpect in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (4.8.0)
# Collecting simplegeneric>0.8
#   Using cached simplegeneric-0.8.1.zip (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygments<2.6
#   Using cached Pygments-2.5.2-py2.py3-none-any.whl (896 kB)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting fake-useragent
#   Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Collecting pyppeteer>=0.0.14
#   Using cached pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Collecting w3lib
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting parse
#   Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Collecting pyquery
#   Using cached pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting sqlparse
#   Using cached sqlparse-0.4.4-py3-none-any.whl (41 kB)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: wcwidth in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (0.2.5)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting appdirs<2.0.0,>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pyee<9.0.0,>=8.1.0
#   Using cached pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: beautifulsoup4 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from bs4->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator) (4.11.1)
# Collecting importlib-metadata>=0.12
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-resources>=5.0 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from fake-useragent->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator) (5.10.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from pexpect->ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (0.7.0)
# Collecting cssselect>=1.2.0
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml>=2.1 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from pyquery->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator) (4.9.2)
# Requirement already satisfied: soupsieve>1.2 in /home/ackc/miniconda3/envs/sprint/lib/python3.7/site-packages (from beautifulsoup4->bs4->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator) (2.3.2.post1)
# Building wheels for collected packages: VariantValidator, biotools, VariantFormatter, vvhgvs, simplegeneric
#   Building wheel for VariantValidator (pyproject.toml) ... done
#   Created wheel for VariantValidator: filename=VariantValidator-2.2.1.dev547+gc16e253-py3-none-any.whl size=216676 sha256=b6186a2f7022ef8db1a34e86297c2d390aa14159b6471c753f4e5c36318c7bdd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4uslwchi/wheels/db/5e/08/e1a1d0adf83c8fe9bd9a209249332097f6f48afe10c47cc92d
#   Building wheel for biotools (setup.py) ... done
#   Created wheel for biotools: filename=biotools-1.2.12-py3-none-any.whl size=35302 sha256=a2c30bd5df23f4dd813d70d5f7f14f16fb4c32bd386bd0474c27f4d3fca30976
#   Stored in directory: /home/ackc/.cache/pip/wheels/e9/d7/77/d9c71affc1447a506416384bd11a4205c59ef29d781440ff5d
#   Building wheel for VariantFormatter (pyproject.toml) ... done
#   Created wheel for VariantFormatter: filename=VariantFormatter-2.2.1.dev54+g0a5aaf5-py3-none-any.whl size=42588 sha256=d4f74798838796b511768c0ec958f2090c4695fff9830316a4b5be05bf9c63d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4uslwchi/wheels/14/42/d3/edccb1866754bd4559b96e3441e035b75f8610fc4179f57809
#   Building wheel for vvhgvs (setup.py) ... done
#   Created wheel for vvhgvs: filename=vvhgvs-2.2.0-py2.py3-none-any.whl size=93812 sha256=4fac211e59f219068775f2df6f2d912101069ce8db8f003c2a6cbc74c392920f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4uslwchi/wheels/94/08/cf/25e279ea3e8081616a58a31c26337ccf1fdd0328d34e714073
#   Building wheel for simplegeneric (setup.py) ... done
#   Created wheel for simplegeneric: filename=simplegeneric-0.8.1-py3-none-any.whl size=5059 sha256=2652eb23a90a2ab217e2720f8cf9da859a6b9254141b545393cd301e90a549b8
#   Stored in directory: /home/ackc/.cache/pip/wheels/39/d7/b9/41b8c09f03813f87f8051e3b9885324ee7a4381172c468e668
# Successfully built VariantValidator biotools VariantFormatter vvhgvs simplegeneric
# Installing collected packages: simplegeneric, pyliftover, pyee, parsley, parse, enum34, biotools, appdirs, websockets, w3lib, VariantFormatter, tqdm, tomli, tabulate, sqlparse, pysam, pyparsing, pygments, psycopg2-binary, protobuf, prompt-toolkit, iniconfig, importlib-metadata, humanfriendly, execnet, exceptiongroup, cssselect, coverage, configparser, yoyo-migrations, pyquery, pyppeteer, pluggy, mysql-connector-python, ipython, httplib2, fake-useragent, coloredlogs, codecov, bs4, bioutils, requests-html, pytest, pytest-xdist, pytest-cov, biocommons.seqrepo, vvhgvs, VariantValidator
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.14.0
#     Uninstalling Pygments-2.14.0:
#       Successfully uninstalled Pygments-2.14.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.36
#     Uninstalling prompt-toolkit-3.0.36:
#       Successfully uninstalled prompt-toolkit-3.0.36
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 6.4.4 requires prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0, but you have prompt-toolkit 1.0.18 which is incompatible.
# ipywidgets 8.0.4 requires ipython>=6.1.0, but you have ipython 5.10.0 which is incompatible.
# ipykernel 6.16.2 requires ipython>=7.23.1, but you have ipython 5.10.0 which is incompatible.
# Successfully installed VariantFormatter-2.2.1.dev54+g0a5aaf5 VariantValidator-2.2.1.dev547+gc16e253 appdirs-1.4.4 biocommons.seqrepo-0.6.5 biotools-1.2.12 bioutils-0.5.7 bs4-0.0.2 codecov-2.1.13 coloredlogs-15.0.1 configparser-5.3.0 coverage-7.2.7 cssselect-1.2.0 enum34-1.1.10 exceptiongroup-1.2.0 execnet-2.0.2 fake-useragent-1.5.1 httplib2-0.22.0 humanfriendly-10.0 importlib-metadata-4.13.0 iniconfig-2.0.0 ipython-5.10.0 mysql-connector-python-8.0.33 parse-1.20.1 parsley-1.3 pluggy-1.2.0 prompt-toolkit-1.0.18 protobuf-3.20.3 psycopg2-binary-2.9.9 pyee-8.2.2 pygments-2.5.2 pyliftover-0.4.1 pyparsing-3.1.2 pyppeteer-1.0.2 pyquery-2.0.0 pysam-0.22.0 pytest-7.4.4 pytest-cov-4.1.0 pytest-xdist-3.5.0 requests-html-0.10.0 simplegeneric-0.8.1 sqlparse-0.4.4 tabulate-0.9.0 tomli-2.0.1 tqdm-4.66.2 vvhgvs-2.2.0 w3lib-2.1.2 websockets-10.4 yoyo-migrations-8.2.0

# %%
! pip list
# Out:
# Package                           Version
# --------------------------------- ---------------------
# aniso8601                         9.0.1
# anyio                             3.6.2
# appdirs                           1.4.4
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# attrs                             22.2.0
# backcall                          0.2.0
# beautifulsoup4                    4.11.1
# biocommons.seqrepo                0.6.5
# biopython                         1.80
# biotools                          1.2.12
# bioutils                          0.5.7
# bleach                            5.0.1
# bs4                               0.0.2
# certifi                           2022.12.7
# cffi                              1.15.1
# charset-normalizer                3.0.1
# click                             8.1.3
# codecov                           2.1.13
# coloredlogs                       15.0.1
# configparser                      5.3.0
# coverage                          7.2.7
# cssselect                         1.2.0
# debugpy                           1.6.5
# decorator                         5.1.1
# defusedxml                        0.7.1
# dicttoxml                         1.7.16
# entrypoints                       0.4
# enum34                            1.1.10
# exceptiongroup                    1.2.0
# execnet                           2.0.2
# fake-useragent                    1.5.1
# fastjsonschema                    2.16.2
# Flask                             1.1.1
# flask-restplus                    0.13.0
# httplib2                          0.22.0
# humanfriendly                     10.0
# idna                              3.4
# importlib-metadata                4.13.0
# importlib-resources               5.10.2
# iniconfig                         2.0.0
# ipykernel                         6.16.2
# ipython                           5.10.0
# ipython-genutils                  0.2.0
# ipywidgets                        8.0.4
# itsdangerous                      2.0.1
# jedi                              0.18.2
# Jinja2                            3.0.3
# jsonschema                        4.17.3
# jupyter                           1.0.0
# jupyter_client                    7.4.8
# jupyter-console                   6.4.4
# jupyter-contrib-core              0.4.2
# jupyter-contrib-nbextensions      0.7.0
# jupyter_core                      4.12.0
# jupyter-highlight-selected-word   0.2.0
# jupyter-nbextensions-configurator 0.6.1
# jupyter-server                    1.23.4
# jupyterlab-pygments               0.2.2
# jupyterlab-widgets                3.0.5
# lxml                              4.9.2
# MarkupSafe                        2.1.1
# matplotlib-inline                 0.1.6
# mistune                           2.0.4
# mysql-connector-python            8.0.33
# nbclassic                         0.4.8
# nbclient                          0.7.2
# nbconvert                         7.2.7
# nbformat                          5.7.1
# nest-asyncio                      1.5.6
# notebook                          6.5.2
# notebook_shim                     0.2.2
# numpy                             1.21.6
# packaging                         23.0
# pandocfilters                     1.5.0
# parse                             1.20.1
# Parsley                           1.3
# parso                             0.8.3
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pip                               22.3.1
# pkgutil_resolve_name              1.3.10
# pluggy                            1.2.0
# prometheus-client                 0.15.0
# prompt-toolkit                    1.0.18
# protobuf                          3.20.3
# psutil                            5.9.4
# psycopg2-binary                   2.9.9
# ptyprocess                        0.7.0
# pycparser                         2.21
# pyee                              8.2.2
# Pygments                          2.5.2
# pyliftover                        0.4.1
# pyparsing                         3.1.2
# pyppeteer                         1.0.2
# pyquery                           2.0.0
# pyrsistent                        0.19.3
# pysam                             0.22.0
# pytest                            7.4.4
# pytest-cov                        4.1.0
# pytest-xdist                      3.5.0
# python-dateutil                   2.8.2
# pytz                              2022.7.1
# PyYAML                            6.0
# pyzmq                             24.0.1
# qtconsole                         5.4.0
# QtPy                              2.3.0
# requests                          2.28.2
# requests-html                     0.10.0
# Send2Trash                        1.8.0
# setuptools                        65.6.3
# simplegeneric                     0.8.1
# six                               1.16.0
# sniffio                           1.3.0
# soupsieve                         2.3.2.post1
# sqlparse                          0.4.4
# tabulate                          0.9.0
# terminado                         0.17.1
# tinycss2                          1.2.1
# tomli                             2.0.1
# tornado                           6.2
# tqdm                              4.66.2
# traitlets                         5.8.1
# typing_extensions                 4.4.0
# urllib3                           1.26.14
# VariantFormatter                  2.2.1.dev54+g0a5aaf5
# VariantValidator                  2.2.1.dev547+gc16e253
# vvhgvs                            2.2.0
# w3lib                             2.1.2
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  1.4.2
# websockets                        10.4
# Werkzeug                          0.16.1
# wheel                             0.37.1
# widgetsnbextension                4.0.5
# yoyo-migrations                   8.2.0
# zipp                              3.11.0

# %%
! python --version
# Out:
# Python 3.7.15

# %%
import importlib_metadata
dir(importlib_metadata)

# https://stackoverflow.com/questions/74505600/no-module-named-importlib-metadata-even-after-installing-it
# Out:
#   File "/tmp/ipykernel_4476/2937529916.py", line 4
#     from importlib_metadata import metadata as importlib.metadata
#                                                         ^
# SyntaxError: invalid syntax

# %%
! conda install python==3.8
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ackc/miniconda3/envs/sprint
#
#   added / updated specs:
#     - python==3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.3.11  |       h06a4308_0         127 KB
#     certifi-2024.2.2           |   py38h06a4308_0         159 KB
#     libedit-3.1.20221030       |       h5eee18b_0         181 KB
#     libffi-3.2.1               |    hf484d3e_1007          48 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-23.3.1                 |   py38h06a4308_0         2.6 MB
#     python-3.8.0               |       h0371630_2        34.9 MB
#     readline-7.0               |       h7b6447c_5         324 KB
#     setuptools-68.2.2          |   py38h06a4308_0         948 KB
#     sqlite-3.33.0              |       h62c20be_0         1.1 MB
#     ------------------------------------------------------------
#                                            Total:        44.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   libedit            pkgs/main/linux-64::libedit-3.1.20221030-h5eee18b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.10.11-h06a4308_0 --> 2024.3.11-h06a4308_0
#   certifi                          2022.12.7-py37h06a4308_0 --> 2024.2.2-py38h06a4308_0
#   openssl                                 1.1.1s-h7f8727e_0 --> 1.1.1w-h7f8727e_0
#   pip                                 22.3.1-py37h06a4308_0 --> 23.3.1-py38h06a4308_0
#   python                                  3.7.15-h7a1cb2a_1 --> 3.8.0-h0371630_2
#   setuptools                          65.6.3-py37h06a4308_0 --> 68.2.2-py38h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   libffi                                   3.4.2-h6a678d5_6 --> 3.2.1-hf484d3e_1007
#   readline                                   8.2-h5eee18b_0 --> 7.0-h7b6447c_5
#   sqlite                                  3.40.1-h5082296_0 --> 3.33.0-h62c20be_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
import VariantValidator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4476/3231780199.py in <module>
# ----> 1 import VariantValidator
#
# ~/miniconda3/envs/sprint/lib/python3.7/site-packages/VariantValidator/__init__.py in <module>
#       1 from . import configure
#       2 from . import logger
# ----> 3 from .version import __version__
#       4
#       5 from .validator import Validator
#
# ~/miniconda3/envs/sprint/lib/python3.7/site-packages/VariantValidator/version.py in <module>
# ----> 1 import importlib.metadata
#       2 import re
#       3 import warnings
#       4
#       5 # Pull in use_scm_version=True enabled version number
#
# ModuleNotFoundError: No module named 'importlib.metadata'

# %%
vval = VariantValidator.Validator()
