# %% [markdown]
# git+https://github.com/openvar/variantValidator@master#egg=VariantValidator
#
# https://github.com/al-baba/rest_variantValidatorFORK/blob/re-create2/rest_variantValidator/app.py
#
# https://github.com/openvar/rest_variantValidator/commit/d865469f5a899d6b3211be1b209009f79342c941
#
# https://docs.pytest.org/en/7.4.x/getting-started.html#getstarted
# https://app.codecov.io/gh/openvar/rest_variantValidator/blob/development4/rest_VariantValidator%2Fendpoints%2Fvariantvalidator_endpoints.py

# %%
import VariantValidator

#vval = VariantValidator.Validator()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import VariantValidator
#
# ModuleNotFoundError: No module named 'VariantValidator'

# %%
! pip install git+https://github.com/openvar/variantValidator@master#egg=VariantValidator
# Out:
# Collecting VariantValidator
#   Cloning https://github.com/openvar/variantValidator (to revision master) to /tmp/pip-install-7ou84k1g/variantvalidator_d1b88448daec48ffb98dc84bde936d07
#   Running command git clone --filter=blob:none --quiet https://github.com/openvar/variantValidator /tmp/pip-install-7ou84k1g/variantvalidator_d1b88448daec48ffb98dc84bde936d07
#   Resolved https://github.com/openvar/variantValidator to commit 1d4df7a667027d3614885e32105c2404db82e8f9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vvhgvs@ git+https://github.com/openvar/vv_hgvs@master (from VariantValidator)
#   Cloning https://github.com/openvar/vv_hgvs (to revision master) to /tmp/pip-install-7ou84k1g/vvhgvs_cf51715a897e4687922060b7c893a254
#   Running command git clone --filter=blob:none --quiet https://github.com/openvar/vv_hgvs /tmp/pip-install-7ou84k1g/vvhgvs_cf51715a897e4687922060b7c893a254
#   Resolved https://github.com/openvar/vv_hgvs to commit 69b1a7c107f3bba1bb43ef1de19c22ba62ff4c80
#   Preparing metadata (setup.py) ... done
# Collecting VariantFormatter@ git+https://github.com/openvar/variantFormatter@master (from VariantValidator)
#   Cloning https://github.com/openvar/variantFormatter (to revision master) to /tmp/pip-install-7ou84k1g/variantformatter_bced44642eca4074a2946679e90535ff
#   Running command git clone --filter=blob:none --quiet https://github.com/openvar/variantFormatter /tmp/pip-install-7ou84k1g/variantformatter_bced44642eca4074a2946679e90535ff
#   Resolved https://github.com/openvar/variantFormatter to commit b76ebc6361986b7da03f362dabe4de4759bd1f53
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting biocommons.seqrepo>=0.5.1 (from VariantValidator)
#   Using cached biocommons.seqrepo-0.6.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting httplib2>=0.9.0 (from VariantValidator)
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 5.5 MB/s eta 0:00:00
# Collecting pyliftover>=0.3 (from VariantValidator)
#   Downloading pyliftover-0.4.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting biotools>=0.3.0 (from VariantValidator)
#   Using cached biotools-1.2.12-py3-none-any.whl
# Collecting mysql-connector-python (from VariantValidator)
#   Downloading mysql_connector_python-8.3.0-cp310-cp310-manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from VariantValidator) (2.31.0)
# Collecting biopython (from VariantValidator)
#   Using cached biopython-1.83-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting pytest>=3.6 (from VariantValidator)
#   Using cached pytest-7.4.4-py3-none-any.whl.metadata (7.9 kB)
# Collecting pytest-cov (from VariantValidator)
#   Using cached pytest_cov-4.1.0-py3-none-any.whl.metadata (26 kB)
# Collecting pytest-xdist (from VariantValidator)
#   Downloading pytest_xdist-3.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting pysam (from VariantValidator)
#   Using cached pysam-0.22.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting codecov (from VariantValidator)
#   Using cached codecov-2.1.13-py2.py3-none-any.whl (16 kB)
# Collecting numpy (from VariantValidator)
#   Downloading numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 11.1 MB/s eta 0:00:00
# Collecting configparser>=3.5.0 (from VariantValidator)
#   Downloading configparser-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting protobuf (from VariantValidator)
#   Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting bioutils>0.4 (from biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached bioutils-0.5.8.post1-py3-none-any.whl.metadata (16 kB)
# Collecting coloredlogs (from biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: ipython in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from biocommons.seqrepo>=0.5.1->VariantValidator) (8.20.0)
# Collecting requests-html (from biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from biocommons.seqrepo>=0.5.1->VariantValidator) (1.16.0)
# Collecting tqdm (from biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting yoyo-migrations (from biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached yoyo_migrations-8.2.0-py3-none-any.whl (48 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2>=0.9.0->VariantValidator)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting iniconfig (from pytest>=3.6->VariantValidator)
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: packaging in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from pytest>=3.6->VariantValidator) (23.1)
# Collecting pluggy<2.0,>=0.12 (from pytest>=3.6->VariantValidator)
#   Downloading pluggy-1.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from pytest>=3.6->VariantValidator) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from pytest>=3.6->VariantValidator) (2.0.1)
# Collecting coverage (from codecov->VariantValidator)
#   Using cached coverage-7.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from requests->VariantValidator) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from requests->VariantValidator) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from requests->VariantValidator) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from requests->VariantValidator) (2023.11.17)
# Collecting execnet>=1.1 (from pytest-xdist->VariantValidator)
#   Downloading execnet-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: attrs>=17.4.0 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from vvhgvs@ git+https://github.com/openvar/vv_hgvs@master->VariantValidator) (23.1.0)
# Collecting enum34 (from vvhgvs@ git+https://github.com/openvar/vv_hgvs@master->VariantValidator)
#   Using cached enum34-1.1.10-py3-none-any.whl (11 kB)
# Collecting ipython (from biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached ipython-5.10.0-py3-none-any.whl (760 kB)
# Collecting parsley (from vvhgvs@ git+https://github.com/openvar/vv_hgvs@master->VariantValidator)
#   Using cached Parsley-1.3-py2.py3-none-any.whl (88 kB)
# Collecting psycopg2-binary (from vvhgvs@ git+https://github.com/openvar/vv_hgvs@master->VariantValidator)
#   Using cached psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: setuptools>=18.5 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (68.2.2)
# Requirement already satisfied: decorator in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (5.1.1)
# Collecting pickleshare (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting simplegeneric>0.8 (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached simplegeneric-0.8.1-py3-none-any.whl
# Requirement already satisfied: traitlets>=4.2 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (5.7.1)
# Collecting prompt-toolkit<2.0.0,>=1.0.4 (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
# Collecting pygments<2.6 (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached Pygments-2.5.2-py2.py3-none-any.whl (896 kB)
# Requirement already satisfied: pexpect in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (4.8.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyquery (from requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached fake_useragent-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting parse (from requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached parse-1.20.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting bs4 (from requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting w3lib (from requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached w3lib-2.1.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Collecting sqlparse (from yoyo-migrations->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached sqlparse-0.4.4-py3-none-any.whl (41 kB)
# Collecting tabulate (from yoyo-migrations->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting importlib-metadata>=3.6.0 (from yoyo-migrations->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=3.6.0->yoyo-migrations->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wcwidth in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (0.2.5)
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer>=0.0.14->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer>=0.0.14->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
# Requirement already satisfied: beautifulsoup4 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from bs4->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator) (4.12.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from pexpect->ipython->biocommons.seqrepo>=0.5.1->VariantValidator) (0.7.0)
# Collecting lxml>=2.1 (from pyquery->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator)
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages (from beautifulsoup4->bs4->requests-html->biocommons.seqrepo>=0.5.1->VariantValidator) (2.5)
# Using cached biocommons.seqrepo-0.6.6-py3-none-any.whl (39 kB)
# Downloading configparser-6.0.0-py3-none-any.whl (19 kB)
# Using cached pytest-7.4.4-py3-none-any.whl (325 kB)
# Using cached biopython-1.83-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Downloading mysql_connector_python-8.3.0-cp310-cp310-manylinux_2_17_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 14.8 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 15.9 MB/s eta 0:00:0000:0100:01
# Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 15.8 MB/s eta 0:00:00
# Using cached pysam-0.22.0-cp310-cp310-manylinux_2_28_x86_64.whl (21.9 MB)
# Using cached pytest_cov-4.1.0-py3-none-any.whl (21 kB)
# Downloading pytest_xdist-3.5.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 9.3 MB/s eta 0:00:00
# Using cached bioutils-0.5.8.post1-py3-none-any.whl (313 kB)
# Using cached coverage-7.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (233 kB)
# Downloading execnet-2.0.2-py3-none-any.whl (37 kB)
# Downloading pluggy-1.4.0-py3-none-any.whl (20 kB)
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 18.8 MB/s eta 0:00:00
# Using cached psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Using cached fake_useragent-1.4.0-py3-none-any.whl (15 kB)
# Using cached parse-1.20.0-py2.py3-none-any.whl (19 kB)
# Using cached w3lib-2.1.2-py3-none-any.whl (21 kB)
# Using cached lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: VariantValidator, pyliftover, VariantFormatter, vvhgvs
#   Building wheel for VariantValidator (pyproject.toml) ... done
#   Created wheel for VariantValidator: filename=VariantValidator-2.2.1.dev521+g1d4df7a-py3-none-any.whl size=214591 sha256=b840b7bfec2047d8c73bd201627bc154df4ffab905e98916ead5c70efe0a0654
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9fpvp14p/wheels/e3/1f/b8/536af125aea30ada2a2cc7f08a843f7a7f4022a1391a043704
#   Building wheel for pyliftover (setup.py) ... done
#   Created wheel for pyliftover: filename=pyliftover-0.4-py3-none-any.whl size=11598 sha256=111c7ff92278ac29f838929fac8e71bad2392f0e76c602c0b6f10033a9c872aa
#   Stored in directory: /home/al_baba/.cache/pip/wheels/38/89/c1/a5771a9e5d79ea18ef8275c2b385386d069ee277d931b10e61
#   Building wheel for VariantFormatter (pyproject.toml) ... done
#   Created wheel for VariantFormatter: filename=VariantFormatter-2.2.1.dev52+gb76ebc6-py3-none-any.whl size=42582 sha256=a7f5976adbb38f0a479a09894f7a5f7620baed0dc2a1890775d0318a601c7a49
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9fpvp14p/wheels/51/e7/8f/2663dbf4038435fc52c88fe1665c82f83f7a8c51f9b37797b2
#   Building wheel for vvhgvs (setup.py) ... done
#   Created wheel for vvhgvs: filename=vvhgvs-2.2.0-py2.py3-none-any.whl size=93807 sha256=0d4a8298d96ed29b0ae36d44a1ba8ec5d4e02accd2b8162537a7752f867057e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9fpvp14p/wheels/ba/2e/d0/4570a1c1859a728914c8d4dd21bd993dd61aea6a62d9c00674
# Successfully built VariantValidator pyliftover VariantFormatter vvhgvs
# Installing collected packages: simplegeneric, pyliftover, pyee, pickleshare, parsley, parse, fake-useragent, enum34, biotools, appdirs, zipp, websockets, w3lib, VariantFormatter, tqdm, tabulate, sqlparse, pysam, pyparsing, pygments, psycopg2-binary, protobuf, prompt-toolkit, pluggy, numpy, mysql-connector-python, lxml, iniconfig, humanfriendly, execnet, cssselect, coverage, configparser, pytest, pyquery, ipython, importlib-metadata, httplib2, coloredlogs, codecov, bs4, bioutils, biopython, yoyo-migrations, pytest-xdist, pytest-cov, pyppeteer, requests-html, biocommons.seqrepo, vvhgvs, VariantValidator
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.15.1
#     Uninstalling Pygments-2.15.1:
#       Successfully uninstalled Pygments-2.15.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.43
#     Uninstalling prompt-toolkit-3.0.43:
#       Successfully uninstalled prompt-toolkit-3.0.43
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.20.0
#     Uninstalling ipython-8.20.0:
#       Successfully uninstalled ipython-8.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipykernel 6.28.0 requires ipython>=7.23.1, but you have ipython 5.10.0 which is incompatible.
# ipywidgets 8.0.4 requires ipython>=6.1.0, but you have ipython 5.10.0 which is incompatible.
# jupyter-console 6.6.3 requires prompt-toolkit>=3.0.30, but you have prompt-toolkit 1.0.18 which is incompatible.
# Successfully installed VariantFormatter-2.2.1.dev52+gb76ebc6 VariantValidator-2.2.1.dev521+g1d4df7a appdirs-1.4.4 biocommons.seqrepo-0.6.6 biopython-1.83 biotools-1.2.12 bioutils-0.5.8.post1 bs4-0.0.2 codecov-2.1.13 coloredlogs-15.0.1 configparser-6.0.0 coverage-7.4.0 cssselect-1.2.0 enum34-1.1.10 execnet-2.0.2 fake-useragent-1.4.0 httplib2-0.22.0 humanfriendly-10.0 importlib-metadata-7.0.1 iniconfig-2.0.0 ipython-5.10.0 lxml-5.1.0 mysql-connector-python-8.3.0 numpy-1.26.3 parse-1.20.0 parsley-1.3 pickleshare-0.7.5 pluggy-1.4.0 prompt-toolkit-1.0.18 protobuf-4.25.2 psycopg2-binary-2.9.9 pyee-8.2.2 pygments-2.5.2 pyliftover-0.4 pyparsing-3.1.1 pyppeteer-1.0.2 pyquery-2.0.0 pysam-0.22.0 pytest-7.4.4 pytest-cov-4.1.0 pytest-xdist-3.5.0 requests-html-0.10.0 simplegeneric-0.8.1 sqlparse-0.4.4 tabulate-0.9.0 tqdm-4.66.1 vvhgvs-2.2.0 w3lib-2.1.2 websockets-10.4 yoyo-migrations-8.2.0 zipp-3.17.0

# %%
! pip list
# Out:
# Package                   Version
# ------------------------- ---------------------
# anyio                     3.5.0
# appdirs                   1.4.4
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# asttokens                 2.0.5
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.11.0
# beautifulsoup4            4.12.2
# biocommons.seqrepo        0.6.6
# biopython                 1.83
# biotools                  1.2.12
# bioutils                  0.5.8.post1
# bleach                    4.1.0
# Brotli                    1.0.9
# bs4                       0.0.2
# certifi                   2023.11.17
# cffi                      1.16.0
# charset-normalizer        2.0.4
# codecov                   2.1.13
# coloredlogs               15.0.1
# comm                      0.1.2
# configparser              6.0.0
# coverage                  7.4.0
# cryptography              41.0.7
# cssselect                 1.2.0
# debugpy                   1.6.7
# decorator                 5.1.1
# defusedxml                0.7.1
# enum34                    1.1.10
# exceptiongroup            1.2.0
# execnet                   2.0.2
# executing                 0.8.3
# fake-useragent            1.4.0
# fastjsonschema            2.16.2
# httplib2                  0.22.0
# humanfriendly             10.0
# idna                      3.4
# importlib-metadata        7.0.1
# iniconfig                 2.0.0
# ipykernel                 6.28.0
# ipython                   5.10.0
# ipywidgets                8.0.4
# jedi                      0.18.1
# Jinja2                    3.1.2
# json5                     0.9.6
# jsonschema                4.19.2
# jsonschema-specifications 2023.7.1
# jupyter                   1.0.0
# jupyter_client            8.6.0
# jupyter-console           6.6.3
# jupyter_core              5.5.0
# jupyter-events            0.8.0
# jupyter-lsp               2.2.0
# jupyter_server            2.10.0
# jupyter_server_terminals  0.4.4
# jupyterlab                4.0.8
# jupyterlab-pygments       0.1.2
# jupyterlab_server         2.25.1
# jupyterlab-widgets        3.0.9
# lxml                      5.1.0
# MarkupSafe                2.1.3
# matplotlib-inline         0.1.6
# mistune                   2.0.4
# mysql-connector-python    8.3.0
# nbclient                  0.8.0
# nbconvert                 7.10.0
# nbformat                  5.9.2
# nest-asyncio              1.5.6
# notebook                  7.0.6
# notebook_shim             0.2.3
# numpy                     1.26.3
# overrides                 7.4.0
# packaging                 23.1
# pandocfilters             1.5.0
# parse                     1.20.0
# Parsley                   1.3
# parso                     0.8.3
# pexpect                   4.8.0
# pickleshare               0.7.5
# pip                       23.3.1
# platformdirs              3.10.0
# pluggy                    1.4.0
# ply                       3.11
# prometheus-client         0.14.1
# prompt-toolkit            1.0.18
# protobuf                  4.25.2
# psutil                    5.9.0
# psycopg2-binary           2.9.9
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pycparser                 2.21
# pyee                      8.2.2
# Pygments                  2.5.2
# pyliftover                0.4
# pyOpenSSL                 23.2.0
# pyparsing                 3.1.1
# pyppeteer                 1.0.2
# PyQt5                     5.15.10
# PyQt5-sip                 12.13.0
# pyquery                   2.0.0
# pysam                     0.22.0
# PySocks                   1.7.1
# pytest                    7.4.4
# pytest-cov                4.1.0
# pytest-xdist              3.5.0
# python-dateutil           2.8.2
# python-json-logger        2.0.7
# pytz                      2023.3.post1
# PyYAML                    6.0.1
# pyzmq                     25.1.2
# qtconsole                 5.5.0
# QtPy                      2.4.1
# referencing               0.30.2
# requests                  2.31.0
# requests-html             0.10.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.10.6
# Send2Trash                1.8.2
# setuptools                68.2.2
# simplegeneric             0.8.1
# sip                       6.7.12
# six                       1.16.0
# sniffio                   1.3.0
# soupsieve                 2.5
# sqlparse                  0.4.4
# stack-data                0.2.0
# tabulate                  0.9.0
# terminado                 0.17.1
# tinycss2                  1.2.1
# tomli                     2.0.1
# tornado                   6.3.3
# tqdm                      4.66.1
# traitlets                 5.7.1
# typing_extensions         4.9.0
# urllib3                   1.26.18
# VariantFormatter          2.2.1.dev52+gb76ebc6
# VariantValidator          2.2.1.dev521+g1d4df7a
# vvhgvs                    2.2.0
# w3lib                     2.1.2
# wcwidth                   0.2.5
# webencodings              0.5.1
# websocket-client          0.58.0
# websockets                10.4
# wheel                     0.41.2
# widgetsnbextension        4.0.5
# yoyo-migrations           8.2.0
# zipp                      3.17.0

# %%
import VariantValidator
# Out:
# MySQL username and password have not been updated from default.
# Please edit your configuration file /home/al_baba/.variantvalidator
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/al_baba/miniconda3/envs/unit-3_repo/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
